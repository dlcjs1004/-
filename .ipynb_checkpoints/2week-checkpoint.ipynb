# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 시각화할 때 한글이 안 꺠지게 폰트 설정 하기

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

#Windows
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
set_matplotlib_formats('retina') #선명하게
# %matplotlib inline

# %% [markdown]
# ##  데이터 불러오기
# - pandas read_csv  활용

# %%
df= pd.read_csv('C:/Users/gram/데이터 분석/소상공인시장진흥공단_상가업소정보_의료기관_201909.csv', low_memory=False)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\gram\데이터 분석

# %%
df.tail(1)
# Out:
#          상가업소번호           상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 91334  16109073  천안김안과천안역본점의원  NaN         S       의료       S01       병원
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# 91334    S01B13     안과의원   Q86201  ...  4413110700102660017016314  김안과
#
#                      도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 91334  충청남도 천안시 동남구 중앙로 92  330952.0  31127.0  NaN  NaN  NaN  127.152651
#
#              위도
# 91334  36.80664
#
# [1 rows x 39 columns]

# %%
df.sample() #임의로 하나 추출
# Out:
#          상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 19101  26036072  광창당한약방  NaN         S       의료       S01       병원    S01B06
#
#       상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 19101      한의원   Q86203  ...  4513012500101150004022692  부부주단
#
#                  도로명주소     구우편번호    신우편번호  동정보  층정보  호정보         경도         위도
# 19101  전라북도 군산시 평화길 26  573240.0  54027.0  NaN  NaN  NaN  126.71891  35.983405
#
# [1 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   지점명        1346 non-null   object
#  3   상권업종대분류코드  91335 non-null  object
#  4   상권업종대분류명   91335 non-null  object
#  5   상권업종중분류코드  91335 non-null  object
#  6   상권업종중분류명   91335 non-null  object
#  7   상권업종소분류코드  91335 non-null  object
#  8   상권업종소분류명   91335 non-null  object
#  9   표준산업분류코드   86413 non-null  object
#  10  표준산업분류명    86413 non-null  object
#  11  시도코드       90956 non-null  float64
#  12  시도명        90956 non-null  object
#  13  시군구코드      90956 non-null  float64
#  14  시군구명       90956 non-null  object
#  15  행정동코드      91335 non-null  int64
#  16  행정동명       90956 non-null  object
#  17  법정동코드      91280 non-null  float64
#  18  법정동명       91280 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 상가업소번호         int64
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드         float64
# 시도명           object
# 시군구코드        float64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드        float64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지          int64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호        float64
# 신우편번호        float64
# 동정보           object
# 층정보           object
# 호정보           object
# 경도           float64
# 위도           float64
# dtype: object

# %% [markdown]
# ### 통계정보를 한번 봅시다

# %%
df["위도"].min()
# Out:
# 33.2192896688307

# %%
df["위도"].max()
# Out:
# 38.499658570559795

# %%
df["위도"].median()
# Out:
# 37.23465231770329

# %%
df["위도"].mean()
# Out:
# 36.62471119236673

# %%
df["위도"].count()
# Out:
# 91335

# %%
df.describe()  #String으로 이루어진 값은 안 나옴
# Out:
#              상가업소번호          시도코드         시군구코드         행정동코드         법정동코드  \
# count  9.133500e+04  90956.000000  90956.000000  9.133500e+04  9.128000e+04
# mean   2.121818e+07     32.586712  32898.381877  3.293232e+09  3.293385e+09
# std    5.042828e+06     13.045138  12985.393171  1.297387e+09  1.297706e+09
# min    2.901108e+06     11.000000  11110.000000  1.111052e+09  1.111010e+09
# 25%    2.001931e+07     26.000000  26350.000000  2.635065e+09  2.635011e+09
# 50%    2.211900e+07     41.000000  41117.000000  4.111758e+09  4.111710e+09
# 75%    2.480984e+07     43.000000  43113.000000  4.311370e+09  4.311311e+09
# max    2.852470e+07     50.000000  50130.000000  5.013061e+09  5.013032e+09
#
#                지번코드        대지구분코드         지번본번지         지번부번지         도로명코드  \
# count  9.133500e+04  91335.000000  91335.000000  72079.000000  9.133500e+04
# mean   3.293191e+18      1.001336    587.534549     17.005092  3.293207e+11
# ...

# %%
df["시도명"].unique()
# Out:
# array(['경기도', '서울특별시', '부산광역시', '강원도', '충청북도', '경상남도', '전라남도', '경상북도',
#        '광주광역시', '대구광역시', '충청남도', '인천광역시', '전라북도', '대전광역시', '울산광역시',
#        '제주특별자치도', '세종특별자치시', nan], dtype=object)

# %%
df["시도명"].head()
# Out:
# 0      경기도
# 1    서울특별시
# 2      경기도
# 3    부산광역시
# 4      경기도
# Name: 시도명, dtype: object

# %%
df["시도명"].nunique() #unique의 개수
# Out:
# 17

# %%
len(df["시도명"].unique()) #unique의 개수
# Out:
# 18

# %%
df["시도명"].value_counts() #내림차순. 각 데이터의 자료 수
# Out:
# 경기도        21374
# 서울특별시      18943
# 부산광역시       6473
# 경상남도        4973
# 인천광역시       4722
# 대구광역시       4597
# 경상북도        4141
# 전라북도        3894
# 충청남도        3578
# 전라남도        3224
# 광주광역시       3214
# 대전광역시       3067
# 충청북도        2677
# 강원도         2634
# 울산광역시       1997
# 제주특별자치도     1095
# 세종특별자치시      353
# Name: 시도명, dtype: int64

# %%
df["시도명"].value_counts().plot.bar()

# %%
df["시도명"].value_counts().plot.barh()

# %%
df["시도명"].value_counts().plot.pie() #원차트

# %%
df["시도명"].value_counts().plot.pie(figsize=(10,10)) #원차트

# %%
sns.countplot(data=df,y="시도명")

# %% [markdown]
# ## 결측치 처리

# %%
df_null_count=df.isnull().sum()
df_null_count
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47291
# 호정보          75784
# 경도               0
# 위도               0
# dtype: int64

# %%
df.isnull() #null은 True로
# Out:
#        상가업소번호    상호명    지점명  상권업종대분류코드  상권업종대분류명  상권업종중분류코드  상권업종중분류명  \
# 0       False  False   True      False     False      False     False
# 1       False  False   True      False     False      False     False
# 2       False  False   True      False     False      False     False
# 3       False  False   True      False     False      False     False
# 4       False  False  False      False     False      False     False
# ...       ...    ...    ...        ...       ...        ...       ...
# 91330   False  False  False      False     False      False     False
# 91331   False  False  False      False     False      False     False
# 91332   False  False   True      False     False      False     False
# 91333   False  False   True      False     False      False     False
# 91334   False  False   True      False     False      False     False
#
#        상권업종소분류코드  상권업종소분류명  표준산업분류코드  ...  건물관리번호    건물명  도로명주소  구우편번호  신우편번호  \
# ...

# %%
df_null_count.plot.barh(figsize=(5,10))

# %%
type(df_null_count)
# Out:
# pandas.core.series.Series

# %%
df_null_count
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47291
# 호정보          75784
# 경도               0
# 위도               0
# dtype: int64

# %%
df_null_count=df_null_count.reset_index()
df_null_count
# Out:
#         index      0
# 0      상가업소번호      0
# 1         상호명      0
# 2         지점명  89989
# 3   상권업종대분류코드      0
# 4    상권업종대분류명      0
# 5   상권업종중분류코드      0
# 6    상권업종중분류명      0
# 7   상권업종소분류코드      0
# 8    상권업종소분류명      0
# 9    표준산업분류코드   4922
# 10    표준산업분류명   4922
# 11       시도코드    379
# 12        시도명    379
# 13      시군구코드    379
# 14       시군구명    379
# 15      행정동코드      0
# 16       행정동명    379
# 17      법정동코드     55
# 18       법정동명     55
# 19       지번코드      0
# 20     대지구분코드      0
# 21      대지구분명      0
# 22      지번본번지      0
# 23      지번부번지  19256
# 24       지번주소      0
# 25      도로명코드      0
# 26        도로명      0
# 27      건물본번지      0
# 28      건물부번지  80731
# 29     건물관리번호      0
# 30        건물명  44882
# 31      도로명주소      0
# 32      구우편번호     12
# 33      신우편번호      2
# 34        동정보  83929
# 35        층정보  47291
# 36        호정보  75784
# 37         경도      0
# 38         위도      0

# %%
df_null_count.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
df_null_count.columns=["컬럼명","결측치수"]
df_null_count
# Out:
#           컬럼명   결측치수
# 0      상가업소번호      0
# 1         상호명      0
# 2         지점명  89989
# 3   상권업종대분류코드      0
# 4    상권업종대분류명      0
# 5   상권업종중분류코드      0
# 6    상권업종중분류명      0
# 7   상권업종소분류코드      0
# 8    상권업종소분류명      0
# 9    표준산업분류코드   4922
# 10    표준산업분류명   4922
# 11       시도코드    379
# 12        시도명    379
# 13      시군구코드    379
# 14       시군구명    379
# 15      행정동코드      0
# 16       행정동명    379
# 17      법정동코드     55
# 18       법정동명     55
# 19       지번코드      0
# 20     대지구분코드      0
# 21      대지구분명      0
# 22      지번본번지      0
# 23      지번부번지  19256
# 24       지번주소      0
# 25      도로명코드      0
# 26        도로명      0
# 27      건물본번지      0
# 28      건물부번지  80731
# 29     건물관리번호      0
# 30        건물명  44882
# 31      도로명주소      0
# 32      구우편번호     12
# 33      신우편번호      2
# 34        동정보  83929
# 35        층정보  47291
# 36        호정보  75784
# 37         경도      0
# 38         위도      0

# %%
df_null_count_sort=df_null_count.sort_values(by="결측치수",ascending=False)
df_null_count
# Out:
#           컬럼명   결측치수
# 0      상가업소번호      0
# 1         상호명      0
# 2         지점명  89989
# 3   상권업종대분류코드      0
# 4    상권업종대분류명      0
# 5   상권업종중분류코드      0
# 6    상권업종중분류명      0
# 7   상권업종소분류코드      0
# 8    상권업종소분류명      0
# 9    표준산업분류코드   4922
# 10    표준산업분류명   4922
# 11       시도코드    379
# 12        시도명    379
# 13      시군구코드    379
# 14       시군구명    379
# 15      행정동코드      0
# 16       행정동명    379
# 17      법정동코드     55
# 18       법정동명     55
# 19       지번코드      0
# 20     대지구분코드      0
# 21      대지구분명      0
# 22      지번본번지      0
# 23      지번부번지  19256
# 24       지번주소      0
# 25      도로명코드      0
# 26        도로명      0
# 27      건물본번지      0
# 28      건물부번지  80731
# 29     건물관리번호      0
# 30        건물명  44882
# 31      도로명주소      0
# 32      구우편번호     12
# 33      신우편번호      2
# 34        동정보  83929
# 35        층정보  47291
# 36        호정보  75784
# 37         경도      0
# 38         위도      0

# %%
df_null_count_sort=df_null_count_sort.head(9)
df_null_count_sort
# Out:
#          컬럼명   결측치수
# 2        지점명  89989
# 34       동정보  83929
# 28     건물부번지  80731
# 36       호정보  75784
# 35       층정보  47291
# 30       건물명  44882
# 23     지번부번지  19256
# 9   표준산업분류코드   4922
# 10   표준산업분류명   4922

# %%
drop_columns=df_null_count_sort["컬럼명"].values
drop_columns
# Out:
# array(['지점명', '동정보', '건물부번지', '호정보', '층정보', '건물명', '지번부번지', '표준산업분류코드',
#        '표준산업분류명'], dtype=object)

# %%
df[drop_columns].head()
# Out:
#    지점명  동정보  건물부번지  호정보  층정보      건물명  지번부번지 표준산업분류코드         표준산업분류명
# 0  NaN  NaN    NaN  NaN  NaN  산호한양아파트    NaN   Q86201           일반 의원
# 1  NaN  NaN    NaN  NaN    4      NaN   14.0   Q86201           일반 의원
# 2  NaN  NaN    NaN  NaN  NaN    한라프라자    1.0   Q86201           일반 의원
# 3  NaN  NaN    NaN  NaN    5      NaN    1.0      NaN             NaN
# 4  수지점  NaN    NaN  NaN    1      NaN    2.0   G47811  의약품 및 의료용품 소매업

# %%
df.shape
# Out:
# (91335, 39)

# %%
df.drop(columns=drop_columns, inplace=True).shape #컬럼이 9개가 삭제됨
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-bbbf70fbacb5> in <module>
# ----> 1 df.drop(columns=drop_columns, inplace=True).shape #컬럼이 9개가 삭제됨
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
df.shape
# Out:
# (91335, 30)

# %%
ex_type=df['상권업종중분류명']=='약국/한약방'
df_medical=df[ex_type]
df_medical.head(9)
# Out:
#       상가업소번호        상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 4   20364049  더블유스토어수지점         S       의료       S02   약국/한약방    S02A01
# 6   20733252      춘산한약방         S       의료       S02   약국/한약방    S02A02
# 7   20582210      부부탕제원         S       의료       S02   약국/한약방    S02A03
# 10  21057519       민생약국         S       의료       S02   약국/한약방    S02A01
# 13  21217689     제중당한약방         S       의료       S02   약국/한약방    S02A02
# 14  21201448      종은한약방         S       의료       S02   약국/한약방    S02A02
# 15  21006553       상명약국         S       의료       S02   약국/한약방    S02A01
# 16  21026027       햇살약국         S       의료       S02   약국/한약방    S02A01
# 24  21228644      화정하나로         S       의료       S02   약국/한약방    S02A01
#
#    상권업종소분류명  시도코드   시도명  ...                     지번주소         도로명코드  \
# 4        약국  41.0   경기도  ...   경기도 용인시 수지구 풍덕천동 712-2  414653205024
# 6       한약방  42.0   강원도  ...         강원도 춘천시 중앙로2가 99  421104454113
# ...

# %%
df_medical.shape
# Out:
# (20923, 30)

# %%
ex_type=df['상권업종중분류명']=='약국/한약방'

# %%
shop_type=df["상권업종대분류명"]=='의료'
df.loc[shop_type,'상권업종중분류명'].value_counts()
# Out:
# 병원          60774
# 약국/한약방      20923
# 수의업          5323
# 유사의료업        3774
# 의료관련서비스업      541
# Name: 상권업종중분류명, dtype: int64

# %%
df_seoul_drug=df[(df['상권업종소분류명']=='약국')&(df["시도명"]=="서울특별시")]
df_seoul_drug.head()
# Out:
#        상가업소번호      상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 33   20816709    이즈타워약         S       의료       S02   약국/한약방    S02A01
# 51   20855710     진흥약국         S       의료       S02   약국/한약방    S02A01
# 130  21589838    신세계약국         S       의료       S02   약국/한약방    S02A01
# 136  22388303  메디팜한솔약국         S       의료       S02   약국/한약방    S02A01
# 141  22412563      명약국         S       의료       S02   약국/한약방    S02A01
#
#     상권업종소분류명  시도코드    시도명  ...                    지번주소         도로명코드  \
# 33        약국  11.0  서울특별시  ...       서울특별시 강남구 역삼동 821  116803122010
# 51        약국  11.0  서울특별시  ...       서울특별시 강동구 둔촌동 630  117403124002
# 130       약국  11.0  서울특별시  ...       서울특별시 중랑구 신내동 646  112603106007
# 136       약국  11.0  서울특별시  ...       서울특별시 성동구 행당동 346  112003103006
# 141       약국  11.0  서울특별시  ...  서울특별시 동대문구 휘경동 286-121  112304115120
#
#                     도로명 건물본번지                     건물관리번호  \
# 33       서울특별시 강남구 테헤란로   101  1168010100108210001000001
# ...

# %%
df_seoul_drug['시군구명'].value_counts()
# Out:
# 강남구     374
# 동대문구    261
# 광진구     212
# 서초구     191
# 송파구     188
# 노원구     169
# 성북구     160
# 은평구     151
# 영등포구    145
# 강서구     136
# 마포구     136
# 중랑구     129
# 서대문구    120
# 관악구     118
# 강동구     117
# 종로구     111
# 양천구     109
# 중구      106
# 강북구     104
# 구로구     102
# 동작구      96
# 성동구      88
# 용산구      87
# 금천구      85
# 도봉구      84
# Name: 시군구명, dtype: int64

# %%
df_seoul_drug['시군구명'].value_counts(normalize=True) #비율이 나타남
# Out:
# 강남구     0.104498
# 동대문구    0.072925
# 광진구     0.059234
# 서초구     0.053367
# 송파구     0.052529
# 노원구     0.047220
# 성북구     0.044705
# 은평구     0.042191
# 영등포구    0.040514
# 강서구     0.037999
# 마포구     0.037999
# 중랑구     0.036044
# 서대문구    0.033529
# 관악구     0.032970
# 강동구     0.032691
# 종로구     0.031014
# 양천구     0.030455
# 중구      0.029617
# 강북구     0.029058
# 구로구     0.028500
# 동작구     0.026823
# 성동구     0.024588
# 용산구     0.024308
# 금천구     0.023750
# 도봉구     0.023470
# Name: 시군구명, dtype: float64

# %%
df_seoul_drug['시군구명'].value_counts().plot.bar()

# %%
df_seoul_drug['시군구명'].value_counts().plot.barh()

# %%
df[df['상호명'].str.contains('대학병원')].head(3)
# Out:
#         상가업소번호           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 193   23651380      동국대학병원일산         S       의료       S01       병원    S01B01
# 363   20632155  경북대학병원응급센터9층         S       의료       S01       병원    S01B01
# 2216  25401601    대구보건대학병원치과         S       의료       S01       병원    S01B04
#
#      상권업종소분류명  시도코드    시도명  ...                  지번주소         도로명코드  \
# 193      종합병원  41.0    경기도  ...  경기도 고양시 일산동구 식사동 814  412853193010
# 363      종합병원  27.0  대구광역시  ...     대구광역시 중구 삼덕동2가 50  271103141005
# 2216     치과의원  27.0  대구광역시  ...    대구광역시 북구 동천동 955-3  272304235200
#
#                    도로명 건물본번지                     건물관리번호                 도로명주소  \
# 193   경기도 고양시 일산동구 동국로    27  4128510100108090004022480   경기도 고양시 일산동구 동국로 27
# 363       대구광역시 중구 동덕로   130  2711010600100500000010507      대구광역시 중구 동덕로 130
# 2216   대구광역시 북구 동천로23길    30  2723012400109550004000001  대구광역시 북구 동천로23길 30-3
#
#          구우편번호    신우편번호          경도         위도
# ...

# %%
df[df['도로명주소'].str.strtwith('서울')].head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-98b80e74f2dc> in <module>
# ----> 1 df[df['도로명주소'].str.strtwith('서울')].head(3)
#
# AttributeError: 'StringMethods' object has no attribute 'strtwith'

# %%
df_seoul= df[df['시도명']=='서울특별시']
df_seoul.head(3)
# Out:
#      상가업소번호       상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 1  20024149  타워광명내과의원         S       의료       S01       병원    S01B07
# 8  20808534    코원성형외과         S       의료       S01       병원    S01B08
# 9  20755460  헬로스마일소아과         S       의료       S01       병원    S01B11
#
#   상권업종소분류명  시도코드    시도명  ...                  지번주소         도로명코드  \
# 1    내과/외과  11.0  서울특별시  ...  서울특별시 강남구 도곡동 467-14  116804166604
# 8  정형/성형외과  11.0  서울특별시  ...   서울특별시 강남구 신사동 592-4  116803121022
# 9      소아과  11.0  서울특별시  ...   서울특별시 강남구 논현동 39-18  116804166129
#
#                  도로명 건물본번지                     건물관리번호                 도로명주소  \
# 1   서울특별시 강남구 언주로30길    39  1168011800104670014000001   서울특별시 강남구 언주로30길 39
# 8      서울특별시 강남구 논현로   826  1168010700105920004010990     서울특별시 강남구 논현로 826
# 9  서울특별시 강남구 논현로131길    30  1168010800100390018000001  서울특별시 강남구 논현로131길 30
#
#       구우편번호   신우편번호          경도         위도
# 1  135270.0  6292.0  127.053198  37.488742
# ...

# %%
df.shape
# Out:
# (91335, 30)

# %%
plt.figure(figsize=(12,9))
sns.countplot(data=df_seoul,y='시군구명')

# %%
df_seoul.plot.scatter(x='경도',y='위도', figsize=(12,9),grid=True)

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(
    data=df_seoul,
    x='경도',
    y='위도',
    hue='시군구명')

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(
    data=df_seoul,
    x='경도',
    y='위도',
    hue='상권업종중분류명')

# %% [markdown]
# #지도그리는 거에특화됨 : forge folium 설치

# %%
import folium

# %%
df_seoul_hospital=df_seoul[df_seoul['상권업종중분류명']=='병원']
df_seoul_hospital.head(3)
# Out:
#      상가업소번호       상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 1  20024149  타워광명내과의원         S       의료       S01       병원    S01B07
# 8  20808534    코원성형외과         S       의료       S01       병원    S01B08
# 9  20755460  헬로스마일소아과         S       의료       S01       병원    S01B11
#
#   상권업종소분류명  시도코드    시도명  ...                  지번주소         도로명코드  \
# 1    내과/외과  11.0  서울특별시  ...  서울특별시 강남구 도곡동 467-14  116804166604
# 8  정형/성형외과  11.0  서울특별시  ...   서울특별시 강남구 신사동 592-4  116803121022
# 9      소아과  11.0  서울특별시  ...   서울특별시 강남구 논현동 39-18  116804166129
#
#                  도로명 건물본번지                     건물관리번호                 도로명주소  \
# 1   서울특별시 강남구 언주로30길    39  1168011800104670014000001   서울특별시 강남구 언주로30길 39
# 8      서울특별시 강남구 논현로   826  1168010700105920004010990     서울특별시 강남구 논현로 826
# 9  서울특별시 강남구 논현로131길    30  1168010800100390018000001  서울특별시 강남구 논현로131길 30
#
#       구우편번호   신우편번호          경도         위도
# 1  135270.0  6292.0  127.053198  37.488742
# ...

# %%
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
x=df_seoul_hospital['위도'].mean()
y=df_seoul_hospital['경도'].mean()
m=folium.Map(location=[x,y],zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for n in df_seoul_hospital.index:
    if(n>100):
        break
    name=df_seoul_hospital.loc[n, '상호명']
    adress=df_seoul_hospital.loc[n,'도로명주소']
    popup_name=f'{name}-{adress}' #팝업
    x=df_seoul_hospital.loc[n,'위도']
    y=df_seoul_hospital.loc[n,'경도']
    location=[x,y]
    
    folium.Marker(
        location=location,
        popup=popup_name
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
